# %%
## improting basic libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.head(10) ## showing first 10 rows of the dataset
# Out:
#     player_id                 name  age gender        country height  weight
# 0   PLID_4964           Keva Horan   23      M        Ukraine    6'2  176lbs  \
# 1  PLID_11234           Herma Tann   18      M         Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F          Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M          Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F      Argentina    5'8  158lbs
# 5  PLID_10351      Tandra Tijerina   21      M         Guinea    6'0  174lbs
# 6  PLID_21799       Narcisa Garnes   24      F       China PR   5'10  148lbs
# 7  PLID_20082           Joyce Boxx   21      F  United States   5'11  168lbs
# 8  PLID_22917       Josette Mcgrew   25      M          Italy    6'0  176lbs
# 9   PLID_9364          Hai Brandel   16      M        Belgium    6'2  183lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot
# ...

# %%
df.shape ## shape of the data set
# Out:
# (13994, 30)

# %%
df.info()
## checking no of entrie sin each column datatype of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
df.describe() ## descrptive statistic data of numerical columns
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance
# count  13994.000000             13581.000000   13994.000000  13994.000000  \
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength
# count    13970.000000               13964.000000     13966.000000  \
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %%
df.describe(include=object)## descrptive statistic data of categorical columns
# Out:
#         player_id        name gender  country height  weight strong_foot
# count       13994       13994  13975    13994  13994   13577       12161  \
# unique      13994       13994      2      163     31      88           3
# top     PLID_4964  Keva Horan      M  England    6'0  165lbs       Right
# freq            1           1   6992     1157   2251    1106        8359
#
#        dedication_level coaching
# count             13994    13869
# unique                3        4
# top              Medium  Academy
# freq               9704     9390

# %%
df.duplicated().sum() ## checkinf duplicate values
# Out:
# 0

# %%
df.nunique()
# Out:
# player_id                    13994
# name                         13994
# age                             39
# gender                           2
# country                        163
# height                          31
# weight                          88
# ball_controlling_skills         89
# body_reflexes                   84
# body_balance                    86
# jumping_skills                  74
# penalties_conversion_rate       86
# mental_strength                 83
# goalkeeping_skills              65
# defending_skills                78
# passing_skills                  77
# dribbling_skills                48
# shot_accuracy                   79
# body_strength_stamina           73
# max_running_speed              166
# strong_foot                      3
# behaviour_rating                64
# matches_played                  18
# fitness_rating                  85
# trophies_won                    10
# dedication_level                 3
# coaching                         4
# ...

# %%
## separating categorical and numerical data
cat_data = [features for features in df.columns if df[features].dtypes == 'O']
num_data = [features for features in df.columns if df[features].dtypes != 'O']

# %%
cat_data
# Out:
# ['player_id',
#  'name',
#  'gender',
#  'country',
#  'height',
#  'weight',
#  'strong_foot',
#  'dedication_level',
#  'coaching']

# %%
df.isna().mean()*100 ## null value percentage in data set
# Out:
# player_id                     0.000000
# name                          0.000000
# age                           0.000000
# gender                        0.135772
# country                       0.000000
# height                        0.000000
# weight                        2.979849
# ball_controlling_skills       2.951265
# body_reflexes                 0.000000
# body_balance                  0.000000
# jumping_skills                0.171502
# penalties_conversion_rate     0.214378
# mental_strength               0.200086
# goalkeeping_skills            0.000000
# defending_skills              0.000000
# passing_skills                0.000000
# dribbling_skills              0.000000
# shot_accuracy                 4.087466
# body_strength_stamina         0.000000
# max_running_speed             0.000000
# strong_foot                  13.098471
# behaviour_rating              5.023582
# matches_played                4.759183
# fitness_rating                4.966414
# ...

# %%
#Checking the count of unique values in categorical features.
unique_count_cat = [{col:len(df[col].unique())} for col in cat_data]  
unique_count_cat
# Out:
# [{'player_id': 13994},
#  {'name': 13994},
#  {'gender': 3},
#  {'country': 163},
#  {'height': 31},
#  {'weight': 89},
#  {'strong_foot': 4},
#  {'dedication_level': 3},
#  {'coaching': 5}]

# %% [markdown]
# ## EDA

# %%
num = df.select_dtypes(include=['float', 'int'])
num.hist(figsize=(20, 16))                  
plt.show()

# %%
cat_features = ['gender',
 'height',
 'weight',
 'strong_foot',
 'dedication_level',
 'coaching','selection']
for feature in cat_features:
    plt.figure(figsize =(20,7))
    
    # Create a count plot
    sns.countplot(data=df, x=feature)
    
    # Set plot title
    plt.title(f'Count Plot for Category {feature}')
    plt.xticks(rotation=90) 
    
    # Show the plot
    plt.show()

# %%
##  Percentage wise Selection status of player based on gender, STrong foot, dedication level and Coaching
features = ['gender',
 'strong_foot',
 'dedication_level',
 'coaching']
for feature in features:
    data = df.copy()
    value = data[['selection',feature]].groupby([feature]).value_counts(normalize=True).unstack()
    percent = value*100
    percent.sort_values(by = 1,ascending = False,inplace = True)

    ax = percent.plot(kind='bar')
    for container in ax.containers:
        ax.bar_label(container, label_type='edge', fontsize=10, padding=3, labels=[f'{x:.1f}%' for x in container.datavalues])
    plt.legend(title='selection_Status', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.title('Percentage wise Selection Status '+ feature)

# %%
df.isna().sum()
# Out:
# player_id                       0
# name                            0
# age                             0
# gender                         19
# country                         0
# height                          0
# weight                        417
# ball_controlling_skills       413
# body_reflexes                   0
# body_balance                    0
# jumping_skills                 24
# penalties_conversion_rate      30
# mental_strength                28
# goalkeeping_skills              0
# defending_skills                0
# passing_skills                  0
# dribbling_skills                0
# shot_accuracy                 572
# body_strength_stamina           0
# max_running_speed               0
# strong_foot                  1833
# behaviour_rating              703
# matches_played                666
# fitness_rating                695
# trophies_won                    0
# dedication_level                0
# coaching                      125
# ...

# %%
num_data
# Out:
# ['age',
#  'ball_controlling_skills',
#  'body_reflexes',
#  'body_balance',
#  'jumping_skills',
#  'penalties_conversion_rate',
#  'mental_strength',
#  'goalkeeping_skills',
#  'defending_skills',
#  'passing_skills',
#  'dribbling_skills',
#  'shot_accuracy',
#  'body_strength_stamina',
#  'max_running_speed',
#  'behaviour_rating',
#  'matches_played',
#  'fitness_rating',
#  'trophies_won',
#  'years_of_experience',
#  'no_of_disqualifications',
#  'selection']

# %%
## Distribution of missig value columns 

features = ['ball_controlling_skills','jumping_skills','penalties_conversion_rate','mental_strength','shot_accuracy','behaviour_rating','matches_played','fitness_rating','years_of_experience']
for feature in features:
    sns.histplot(df[feature],kde = True)
    plt.show()

# %% [markdown]
# ### Null Value Handleing

# %%
df.isna().mean()*100 ## null value in percentage wise
# Out:
# player_id                     0.000000
# name                          0.000000
# age                           0.000000
# gender                        0.135772
# country                       0.000000
# height                        0.000000
# weight                        2.979849
# ball_controlling_skills       2.951265
# body_reflexes                 0.000000
# body_balance                  0.000000
# jumping_skills                0.171502
# penalties_conversion_rate     0.214378
# mental_strength               0.200086
# goalkeeping_skills            0.000000
# defending_skills              0.000000
# passing_skills                0.000000
# dribbling_skills              0.000000
# shot_accuracy                 4.087466
# body_strength_stamina         0.000000
# max_running_speed             0.000000
# strong_foot                  13.098471
# behaviour_rating              5.023582
# matches_played                4.759183
# fitness_rating                4.966414
# ...

# %% [markdown]
# strong_foot                  13.098471% null value,
# behaviour_rating              5.023582% null value,
# matches_played                4.759183% null value,
# fitness_rating                4.966414% null value,
# years_of_experience           1.029012% null value,
# shot_accuracy                 4.087466% null value,
# weight                        2.979849% null value,
# ball_controlling_skills       2.951265% null value,
# jumping_skills                0.171502% null value,
# penalties_conversion_rate     0.214378% null value,
# mental_strength               0.200086% null value,
# gender                        0.135772% null value

# %%
## Weight has missing value and is object datatype changing it to numberical type 
# Extract numeric values and convert to numeric data type
df['weight'] = df['weight'].str.extract('(\d+)').astype(float)

# %%
df.weight.dtype
# Out:
# dtype('float64')

# %%
sns.histplot(df['weight'],kde =True)
plt.show()

# %%
df['weight']=df['weight'].fillna(df['weight'].mean())

# %%
df['ball_controlling_skills']=df['ball_controlling_skills'].fillna(df['ball_controlling_skills'].median())
df['jumping_skills']=df['jumping_skills'].fillna(df['jumping_skills'].median())
df['penalties_conversion_rate']=df['penalties_conversion_rate'].fillna(df['penalties_conversion_rate'].median())
df['mental_strength']=df['mental_strength'].fillna(df['mental_strength'].mean())
df['shot_accuracy']=df['shot_accuracy'].fillna(df['shot_accuracy'].median())
df['behaviour_rating']=df['behaviour_rating'].fillna(df['behaviour_rating'].median())
df['fitness_rating']=df['fitness_rating'].fillna(df['fitness_rating'].median())
df['years_of_experience']=df['years_of_experience'].fillna(df['years_of_experience'].median())

# %%
df['gender'].mode(),df['strong_foot'].mode(),df['coaching'].mode()
# Out:
# (0    M
#  Name: gender, dtype: object,
#  0    Right
#  Name: strong_foot, dtype: object,
#  0    Academy
#  Name: coaching, dtype: object)

# %%
df['gender']=df['gender'].fillna(df['gender'].mode()[0])
df['strong_foot']=df['strong_foot'].fillna(df['strong_foot'].mode()[0])
df['coaching']=df['coaching'].fillna(df['coaching'].mode()[0])

# %%
df['matches_played']=df['matches_played'].fillna(df['matches_played'].median())

# %%
df.isna().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# ...

# %% [markdown]
# ### Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13994 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  float64
#  6   weight                     13994 non-null  float64
#  7   ball_controlling_skills    13994 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13994 non-null  float64
#  11  penalties_conversion_rate  13994 non-null  float64
#  12  mental_strength            13994 non-null  float64
# ...

# %%
# Replace the single quote with a period and convert to numeric
df['height'] = df['height'].str.replace("'", '.').str.replace('"', '').astype(float)

# %%
df.head()
# Out:
#     player_id                 name  age gender    country  height  weight
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6.20   176.0  \
# 1  PLID_11234           Herma Tann   18      M     Russia    5.10   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6.20   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile    5.11   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5.80   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot
# 0                     77.0           58.0          47.0  ...        Right  \
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won
# ...

# %%
df['dedication_level'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
##ordinal encoding dedication level column
from sklearn.preprocessing import OrdinalEncoder


dedication = ['Low',"Medium","High"]

enc = OrdinalEncoder(categories=[dedication])

df[['dedication_level']] = enc.fit_transform(df[['dedication_level']])

# %%
##onehotencoding on gender and recruitmentchannel Department
from numpy import int32
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False,dtype=int32,drop='first')
cols = df[['gender','strong_foot','coaching']]
onehot_encoded = ohe.fit_transform(cols)
# Out:
# C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
feature_names = ohe.get_feature_names_out(['gender','strong_foot','coaching'])
# Create a new DataFrame with the encoded data and feature names
df_encoded = pd.DataFrame(onehot_encoded, columns=feature_names)
# Concatenate the original DataFrame and the encoded DataFrame
df = pd.concat([df, df_encoded], axis=1)

# %%
df.drop(['gender','strong_foot','coaching'],axis=1,inplace=True)

# %%
cat_data = [features for features in df.columns if df[features].dtypes == 'O']
cat_data
# Out:
# ['player_id', 'name', 'country']

# %% [markdown]
# ### Feature reduction

# %%
## Player id,name, and country does not have realtion in selection of players do droping them
df.drop(['player_id', 'name', 'country'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age  height  weight  ball_controlling_skills  body_reflexes  body_balance
# 0   23    6.20   176.0                     77.0           58.0          47.0  \
# 1   18    5.10   148.0                     54.0           69.0          70.0
# 2   16    6.20   172.0                     34.0           43.0          45.0
# 3   27    5.11   165.0                     79.0           73.0          76.0
# 4   19    5.80   158.0                     47.0           61.0          74.0
#
#    jumping_skills  penalties_conversion_rate  mental_strength
# 0            59.0                       41.0             73.0  \
# 1            62.0                       53.0             43.0
# 2            69.0                       49.0             45.0
# 3            86.0                       81.0             80.0
# 4            57.0                       49.0             35.0
#
#    goalkeeping_skills  ...  dedication_level  years_of_experience
# ...

# %% [markdown]
# ## Spliting data

# %%
## spliting dependent and independent variable
x=df.drop('selection',axis=1)
y=df['selection']

# %%
y.value_counts(normalize=True)  # data is no high imbalance between data
# Out:
# selection
# 1    0.557525
# 0    0.442475
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=123)

# %% [markdown]
# #### Training and testing  model

# %%
from sklearn.metrics import confusion_matrix , accuracy_score, precision_score, recall_score, f1_score,classification_report

# %%
# 1. Logistic Regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr_model=lr.fit(x_train,y_train)
lr_pred=lr_model.predict(x_test)


# 2. SVM
from sklearn.svm import SVC
svc = SVC() 
svc_model=svc.fit(x_train,y_train)
svm_pred = svc_model.predict(x_test)

#3. Desicion Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt_model=dt.fit(x_train,y_train)
dt_pred=dt_model.predict(x_test)


# 4.Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf_model=rf.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)

from xgboost import XGBClassifier
xg = XGBClassifier()
xg_model = xg.fit(x_train,y_train)
xg_pred=xg_model.predict(x_test)


## Accuracy

print('Logistic Regression Accuracy is : ', accuracy_score(y_test, lr_pred))
print('SVC Model Accuracy is: ', accuracy_score(y_test, svm_pred))
print('Decision Tree Accuracy is: ', accuracy_score(y_test, dt_pred))
print('Random FOrest Accuracy is: ', accuracy_score(y_test, rf_pred))
print('XG boost Accuracy is: ', accuracy_score(y_test, xg_pred))
# Out:
# C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy is :  0.7539296941983424
# SVC Model Accuracy is:  0.7822234924264075
# Decision Tree Accuracy is:  0.7905115747356387
# Random FOrest Accuracy is:  0.854815661617605
# XG boost Accuracy is:  0.8619605601600457

# %%
print('Logistic Regression Report is : \n', classification_report(y_test, lr_pred))
print('SVC Model report is: \n', classification_report(y_test, svm_pred))
print('Decision Tree Report is: \n', classification_report(y_test, dt_pred))
print('Random FOrest Report is: \n', classification_report(y_test, rf_pred))
print('XG boost Report is: \n', classification_report(y_test, xg_pred))
# Out:
# Logistic Regression Report is :
#                precision    recall  f1-score   support
#
#            0       0.73      0.70      0.72      1549
#            1       0.77      0.79      0.78      1950
#
#     accuracy                           0.75      3499
#    macro avg       0.75      0.75      0.75      3499
# weighted avg       0.75      0.75      0.75      3499
#
# SVC Model report is:
#                precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76      1549
#            1       0.81      0.80      0.80      1950
#
#     accuracy                           0.78      3499
#    macro avg       0.78      0.78      0.78      3499
# weighted avg       0.78      0.78      0.78      3499
#
# Decision Tree Report is:
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77      1549
#            1       0.82      0.80      0.81      1950
#
#     accuracy                           0.79      3499
# ...

# %% [markdown]
# ## Cross validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
skfold_validator = StratifiedKFold(n_splits=10)

# %%
#Logistic Regression
skcv_result = cross_val_score(lr_model, x, y, cv=skfold_validator)
np.mean(skcv_result)
# Out:
# C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
#SVC model
skcv_result = cross_val_score(svc_model, x, y, cv=skfold_validator)
np.mean(skcv_result)
# Out:
# 0.786909016644542

# %%
#Decision Tree
skcv_result = cross_val_score(dt_model, x, y, cv=skfold_validator)
np.mean(skcv_result)
# Out:
# 0.7871229960175635

# %%
#Random Forest
skcv_result = cross_val_score(rf_model, x, y, cv=skfold_validator)
np.mean(skcv_result)
# Out:
# 0.8584389359746758

# %%
skcv_result = cross_val_score(xg_model, x, y, cv=skfold_validator)
np.mean(skcv_result)
# Out:
# 0.8583671500051058

# %% [markdown]
# #####  After cross validation Random Forest is the selected model

# %% [markdown]
# ### Hypertuning

# %%
n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
max_features = ['auto','sqrt','log2']
max_depth = [int(x) for x in np.linspace(start=10, stop=1000, num=10)]
min_samples_split = [2,5,10,14]
min_samples_leaf = [1,2,4,6,8]

# %%
random_grid = {'n_estimators':n_estimators,
               'max_features' :max_features,
               'max_depth' : max_depth,
               'min_samples_split' : min_samples_split,
               'min_samples_leaf':min_samples_leaf,
               'criterion': ['entropy','gini','log_loss']}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf_randomcv = RandomizedSearchCV(estimator = rf,param_distributions=random_grid,scoring='accuracy',
                                 n_iter = 100, cv=3, verbose=2,random_state=100, n_jobs=-1)
rf_randomcv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 96 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 59 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shree\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 1400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 1000,
#  'criterion': 'entropy'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'],
                         rf_randomcv.best_params_['min_samples_leaf']+2,
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'],
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100,
                     rf_randomcv.best_params_['n_estimators'],
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['entropy'], 'max_depth': [1000], 'max_features': ['sqrt'], 'min_samples_leaf': [2, 4, 6], 'min_samples_split': [0, 1, 2, 3, 4], 'n_estimators': [1200, 1300, 1400, 1500, 1600]}

# %%
grid_search = GridSearchCV(estimator=rf,param_grid = param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[148], line 2
#       1 grid_search = GridSearchCV(estimator=rf,param_grid = param_grid,cv=10,n_jobs=-1,verbose=2)
# ----> 2 grid_search.fit(x_train,y_train)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
best_params = grid_search.best_params_
best_param_model = grid_search.best_estimator_

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf_model=rf.fit(x_train,y_train)
y_pred=rf_model.predict(x_test)

print('Accuracy = ',accuracy_score(y_test,y_pred))
print('Precision = ',precision_score(y_test,y_pred))
print('Recall = ',recall_score(y_test,y_pred))
print('F1 Score = ',f1_score(y_test,y_pred))
# Out:
# Accuracy =  0.8593883966847671
# Precision =  0.8769389865563598
# Recall =  0.8697435897435898
# F1 Score =  0.8733264675592173
